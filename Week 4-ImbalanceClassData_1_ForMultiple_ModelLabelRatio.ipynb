# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 1. Some subroutines

# %%
def get_bcw() :
    bcw = pd.read_csv('~/Downloads/wdbc.data' , header=None)
    column_names = ['id','malignant',
                'nucleus_mean','nucleus_se','nucleus_worst',
                'texture_mean','texture_se','texture_worst',
                'perimeter_mean','perimeter_se','perimeter_worst',
                'area_mean','area_se','area_worst',
                'smoothness_mean','smoothness_se','smoothness_worst',
                'compactness_mean','compactness_se','compactness_worst',
                'concavity_mean','concavity_se','concavity_worst',
                'concave_pts_mean','concave_pts_se','concave_pts_worst',
                'symmetry_mean','symmetry_se','symmetry_worst',
                'fractal_dim_mean','fractal_dim_se','fractal_dim_worst']

    bcw.columns = column_names
    
    bcw['malignant'] = bcw['malignant'].map(lambda x: 0 if x == "B" else 1)

    # make a copy for two purposes:
    # 1. keep the original data intake for futural reference.
    # 2. use the same dataset name "mydata" for later processing
    # so that we use the same code for different dataset.

    #     X = mydata[['nucleus_mean','texture_mean','perimeter_mean']]
    X = bcw.drop(columns=['id', 'malignant']).values

    from sklearn.preprocessing import StandardScaler
    ss = StandardScaler()
    X = ss.fit_transform(X)
    
    
    y = bcw['malignant'].values
    return X, y

# %%
def evaluate(pred, expect) :
    ans = pred - expect
    error_sum = ans.sum()
    n_errors = abs(ans).sum()
    accuracy = 1 - n_errors / expect.shape[0]
    
    return round(accuracy, 3) , n_errors, error_sum

# %%
from sklearn.metrics import confusion_matrix
actual = [1, 0, 1, 0, 0, 1, 0, 0, 1, 0]
predicted = [1, 0, 0, 0, 1, 0, 0, 0, 1, 0]
tn, fp, fn, tp = confusion_matrix(actual, predicted).ravel()
print(2*(0.67*0.5)/(0.67+0.5))
print(2 / ( (1/ (tp/(tp+fp))) + (1/ (tp/(tp+fn))) ))
# Out:
# 0.5726495726495727
# 0.5714285714285714

# %% [markdown]
# # 2. get dataset

# %%
X, y = get_bcw()   # X: feature vector, y label

# %%
y.sum()
# Out:
# 212

# %%
y.shape
# Out:
# (569,)

# %%
212/569
# Out:
# 0.37258347978910367

# %%
37/63
# Out:
# 0.5873015873015873

# %%
X_orig = X
y_orig = y

bcw = pd.DataFrame(X)
bcw.columns = [
                'nucleus_mean','nucleus_se','nucleus_worst',
                'texture_mean','texture_se','texture_worst',
                'perimeter_mean','perimeter_se','perimeter_worst',
                'area_mean','area_se','area_worst',
                'smoothness_mean','smoothness_se','smoothness_worst',
                'compactness_mean','compactness_se','compactness_worst',
                'concavity_mean','concavity_se','concavity_worst',
                'concave_pts_mean','concave_pts_se','concave_pts_worst',
                'symmetry_mean','symmetry_se','symmetry_worst',
                'fractal_dim_mean','fractal_dim_se','fractal_dim_worst']
bcw['malignant'] = y

bcw.head()
# Out:
#    nucleus_mean  nucleus_se  nucleus_worst  texture_mean  texture_se  \
# 0      1.097064   -2.073335       1.269934      0.984375    1.568466
# 1      1.829821   -0.353632       1.685955      1.908708   -0.826962
# 2      1.579888    0.456187       1.566503      1.558884    0.942210
# 3     -0.768909    0.253732      -0.592687     -0.764464    3.283553
# 4      1.750297   -1.151816       1.776573      1.826229    0.280372
#
#    texture_worst  perimeter_mean  perimeter_se  perimeter_worst  area_mean  \
# 0       3.283515        2.652874      2.532475         2.217515   2.255747
# 1      -0.487072       -0.023846      0.548144         0.001392  -0.868652
# 2       1.052926        1.363478      2.037231         0.939685  -0.398008
# 3       3.402909        1.915897      1.451707         2.867383   4.910919
# 4       0.539340        1.371011      1.428493        -0.009560  -0.562450
#
#    ...  concave_pts_mean  concave_pts_se  concave_pts_worst  symmetry_mean  \
# 0  ...         -1.359293        2.303601           2.001237       1.307686
# 1  ...         -0.369203        1.535126           1.890489      -0.375612
# 2  ...         -0.023974        1.347475           1.456285       0.527407
# 3  ...          0.133984       -0.249939          -0.550021       3.394275
# 4  ...         -1.466770        1.338539           1.220724       0.220556
#
#    symmetry_se  symmetry_worst  fractal_dim_mean  fractal_dim_se  \
# 0     2.616665        2.109526          2.296076        2.750622
# 1    -0.430444       -0.146749          1.087084       -0.243890
# 2     1.082932        0.854974          1.955000        1.152255
# 3     3.893397        1.989588          2.175786        6.046041
# 4    -0.313395        0.613179          0.729259       -0.868353
#
#    fractal_dim_worst  malignant
# 0           1.937015          1
# 1           0.281190          1
# 2           0.201391          1
# 3           4.935010          1
# 4          -0.397100          1
#
# [5 rows x 31 columns]

# %%
bcw.columns
# Out:
# Index(['nucleus_mean', 'nucleus_se', 'nucleus_worst', 'texture_mean',
#        'texture_se', 'texture_worst', 'perimeter_mean', 'perimeter_se',
#        'perimeter_worst', 'area_mean', 'area_se', 'area_worst',
#        'smoothness_mean', 'smoothness_se', 'smoothness_worst',
#        'compactness_mean', 'compactness_se', 'compactness_worst',
#        'concavity_mean', 'concavity_se', 'concavity_worst', 'concave_pts_mean',
#        'concave_pts_se', 'concave_pts_worst', 'symmetry_mean', 'symmetry_se',
#        'symmetry_worst', 'fractal_dim_mean', 'fractal_dim_se',
#        'fractal_dim_worst', 'malignant'],
#       dtype='object')

# %%
cols = bcw.columns
['malignant'] + list(cols[:-1])
# Out:
# ['malignant',
#  'nucleus_mean',
#  'nucleus_se',
#  'nucleus_worst',
#  'texture_mean',
#  'texture_se',
#  'texture_worst',
#  'perimeter_mean',
#  'perimeter_se',
#  'perimeter_worst',
#  'area_mean',
#  'area_se',
#  'area_worst',
#  'smoothness_mean',
#  'smoothness_se',
#  'smoothness_worst',
#  'compactness_mean',
#  'compactness_se',
#  'compactness_worst',
#  'concavity_mean',
#  'concavity_se',
#  'concavity_worst',
#  'concave_pts_mean',
#  'concave_pts_se',
#  'concave_pts_worst',
#  'symmetry_mean',
#  'symmetry_se',
#  'symmetry_worst',
#  'fractal_dim_mean',
#  'fractal_dim_se',
#  'fractal_dim_worst']

# %%
# try to move 'malignant' column to the front.
cols = bcw.columns
# print(['malignant'] + list(cols[:-1]))
bcw = bcw[['malignant'] + list(cols[:-1])]
bcw.head()
# Out:
#    malignant  nucleus_mean  nucleus_se  nucleus_worst  texture_mean  \
# 0          1      1.097064   -2.073335       1.269934      0.984375
# 1          1      1.829821   -0.353632       1.685955      1.908708
# 2          1      1.579888    0.456187       1.566503      1.558884
# 3          1     -0.768909    0.253732      -0.592687     -0.764464
# 4          1      1.750297   -1.151816       1.776573      1.826229
#
#    texture_se  texture_worst  perimeter_mean  perimeter_se  perimeter_worst  \
# 0    1.568466       3.283515        2.652874      2.532475         2.217515
# 1   -0.826962      -0.487072       -0.023846      0.548144         0.001392
# 2    0.942210       1.052926        1.363478      2.037231         0.939685
# 3    3.283553       3.402909        1.915897      1.451707         2.867383
# 4    0.280372       0.539340        1.371011      1.428493        -0.009560
#
#    ...  concavity_worst  concave_pts_mean  concave_pts_se  concave_pts_worst  \
# 0  ...         1.886690         -1.359293        2.303601           2.001237
# 1  ...         1.805927         -0.369203        1.535126           1.890489
# 2  ...         1.511870         -0.023974        1.347475           1.456285
# 3  ...        -0.281464          0.133984       -0.249939          -0.550021
# 4  ...         1.298575         -1.466770        1.338539           1.220724
#
#    symmetry_mean  symmetry_se  symmetry_worst  fractal_dim_mean  \
# 0       1.307686     2.616665        2.109526          2.296076
# 1      -0.375612    -0.430444       -0.146749          1.087084
# 2       0.527407     1.082932        0.854974          1.955000
# 3       3.394275     3.893397        1.989588          2.175786
# 4       0.220556    -0.313395        0.613179          0.729259
#
#    fractal_dim_se  fractal_dim_worst
# 0        2.750622           1.937015
# 1       -0.243890           0.281190
# 2        1.152255           0.201391
# 3        6.046041           4.935010
# 4       -0.868353          -0.397100
#
# [5 rows x 31 columns]

# %% [markdown]
# # 3. Split Data into Training and Testing
# --------
# Choose 3.1  and 3.2 to get the type of split data you want to train.

# %%
bcw.malignant.sum()
# Out:
# 212

# %% [markdown]
# # 3.1 Original Data Split

# %%
from sklearn.model_selection import train_test_split

print(X.shape)
print(y.shape)
print(type(X))
print(type(y))
# numpy array does not have column names.  
# We can only use the slice [row_start:row_end:step_row, col_start:col_end:step_col]
# to select rows and cols we want
# be aware that row_end and col_end are not inclusive
# the format of the output will be discussed in another lecture.
print(X[0:6:2])
print(y[0:40:4])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state=2018)
# Out:
# (569, 30)
# (569,)
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# [[ 1.09706398 -2.07333501  1.26993369  0.9843749   1.56846633  3.28351467
#    2.65287398  2.53247522  2.21751501  2.25574689  2.48973393 -0.56526506
#    2.83303087  2.48757756 -0.21400165  1.31686157  0.72402616  0.66081994
#    1.14875667  0.90708308  1.88668963 -1.35929347  2.30360062  2.00123749
#    1.30768627  2.61666502  2.10952635  2.29607613  2.75062224  1.93701461]
#  [ 1.57988811  0.45618695  1.56650313  1.55888363  0.94221044  1.05292554
#    1.36347845  2.03723076  0.93968482 -0.39800791  1.22867595 -0.78008338
#    0.8509283   1.18133606 -0.29700501  0.8149735   0.21307643  1.42482747
#    0.23703554  0.2935594   1.51187025 -0.02397438  1.34747521  1.45628455
#    0.52740741  1.08293217  0.85497394  1.95500035  1.152255    0.20139121]
#  [ 1.75029663 -1.15181643  1.77657315  1.82622928  0.28037183  0.53934045
#    1.37101143  1.42849277 -0.00956047 -0.56244998  1.27054278 -0.7902437
#    1.27318941  1.19035676  1.48306716 -0.04851988  0.82847078  1.14420474
#   -0.36109227  0.49932813  1.29857524 -1.46677038  1.33853946  1.22072425
#    0.22055617 -0.31339451  0.61317876  0.72925926 -0.86835298 -0.39709962]]
# [1 1 1 1 1 0 1 1 1 1]

# %% [markdown]
# # 3.2 Data Split to Get Imbalanced Labels in Training Data

# %%
def GetImbalancedLabelData(DF_orig, label_ratio) :
    import copy as copy
    from sklearn.model_selection import train_test_split
    DF = copy.copy(DF_orig)
    DF1 = DF[DF.malignant == 1]
    DF0 = DF[DF.malignant == 0]
    
    Test_Size= 0.25  # intended test size.  The actual size depend on how the train data is arranged.
    # Simple implementation : 
    #      split both DF0 with Test_Size and DF1 with label_ratio 
    #      This method can not produce the right label_ratio for training set. 
#     TestSizeFrom0 =  Test_Size
    # instead , the following 2 statement, can split the training data in the precise label_ratio.
    max_train0_size = min(DF0.shape[0], DF1.shape[0])  
    TestSizeFrom0 = 1 -  min(max_train0_size, DF0.shape[0] * (1- Test_Size) ) / DF0.shape[0]
    
    
    DF0_train, DF0_test = train_test_split(DF0, test_size = TestSizeFrom0, random_state=2018)
    DF1_train, DF1_test = train_test_split(DF1, test_size =  (1 - label_ratio), random_state=2018)
    
    DF_train = pd.concat((DF0_train, DF1_train) )
    DF_test = pd.concat((DF0_test, DF1_test) )
    
    y_train = DF_train.malignant.values
    X_train = DF_train.drop(columns=[ 'malignant']).values
    y_test = DF_test.malignant.values
    X_test = DF_test.drop(columns=[ 'malignant']).values

    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = GetImbalancedLabelData(bcw, 0.8)
print(y_train.sum(), y_train.shape,  y_test.sum(), y_test.shape,)
print(y_train.sum()/( y_train.shape[0] - y_train.sum() )  )
# Out:
# 169 (381,) 43 (188,)
# 0.7971698113207547

# %% [markdown]
# # 4. Build ML/DL model (model specific)

# %%
def RunAll(bcw, label_ratio, default = 1) :
    
    # default: 1 for default class_weight (or default weights if KNN)
    # default: 0 forclass_weight = balanced (or weights = 'distance' if KNN)
    
    X_train, X_test, y_train, y_test = GetImbalancedLabelData(bcw, label_ratio)    
    LabelRatio = (y_train.sum() / ( y_train.shape[0] - y_train.sum()))
    
    results = []
    
    from sklearn.tree import DecisionTreeClassifier
    if default :
        DT = DecisionTreeClassifier()
    else:
        DT = DecisionTreeClassifier(class_weight='balanced') # default:None, other: balanced
    model = DT
    model.fit(X_train, y_train)
    pred = model.predict(X_test)
    results = results + [['DT', default, round(LabelRatio, 2) ] + list( evaluate(pred, y_test))]
    

    from sklearn.ensemble import RandomForestClassifier
    if default :
        RF = RandomForestClassifier(n_estimators =50)
    else:
        RF = RandomForestClassifier(n_estimators =50, class_weight='balanced') # default:None, other: balanced    
    model = RF
    model.fit(X_train, y_train)
    pred = model.predict(X_test)
    results = results + [['RF', default, round(LabelRatio, 2) ] + list( evaluate(pred, y_test))]
    
        
    from sklearn.neighbors import KNeighborsClassifier
    if default :
        KNN = KNeighborsClassifier()
    else:
        KNN = KNeighborsClassifier(weights = 'distance') # default:uniform, other: distance    
#     KNN = KNeighborsClassifier()
    model = KNN
    model.fit(X_train, y_train)
    pred = model.predict(X_test)
    results = results + [['KNN', default, round(LabelRatio, 2) ] + list( evaluate(pred, y_test))]
    
        
    from sklearn.svm import SVC
    if default :
        SVM = SVC(gamma='scale')
    else:
        SVM = SVC(gamma='scale', class_weight='balanced') # default:None, other: balanced
    model = SVM
    model.fit(X_train, y_train)
    pred = model.predict(X_test)
    results = results + [['SVM', default, round(LabelRatio, 2) ] + list( evaluate(pred, y_test))]
    
    
    return results

# %%
RunAll(bcw, 0.8, default = 1)
# Out:
# [['DT', 1, 0.8, 0.926, 14, 8],
#  ['RF', 1, 0.8, 0.973, 5, 3],
#  ['KNN', 1, 0.8, 0.995, 1, -1],
#  ['SVM', 1, 0.8, 0.973, 5, 3]]

# %%
RunAll(bcw, 0.8, default = 0)
# Out:
# [['DT', 0, 0.8, 0.947, 10, 4],
#  ['RF', 0, 0.8, 0.968, 6, 4],
#  ['KNN', 0, 0.8, 0.995, 1, -1],
#  ['SVM', 0, 0.8, 0.973, 5, 3]]

# %%
Default = []
for i in range(10, 100) :
    labelratio = 0.01 * i  # i: 10--99, ---> 0.1 --0.99
    Default = Default + RunAll(bcw, labelratio, 1)
    
Default
# Out:
# [['DT', 1, 0.1, 0.884, 39, -29],
#  ['RF', 1, 0.1, 0.872, 43, -43],
#  ['KNN', 1, 0.1, 0.818, 61, -61],
#  ['SVM', 1, 0.1, 0.833, 56, -56],
#  ['DT', 1, 0.11, 0.886, 38, -32],
#  ['RF', 1, 0.11, 0.877, 41, -41],
#  ['KNN', 1, 0.11, 0.823, 59, -59],
#  ['SVM', 1, 0.11, 0.841, 53, -53],
#  ['DT', 1, 0.12, 0.886, 38, -36],
#  ['RF', 1, 0.12, 0.877, 41, -39],
#  ['KNN', 1, 0.12, 0.837, 54, -54],
#  ['SVM', 1, 0.12, 0.861, 46, -46],
#  ['DT', 1, 0.13, 0.906, 31, -21],
#  ['RF', 1, 0.13, 0.903, 32, -32],
#  ['KNN', 1, 0.13, 0.842, 52, -52],
#  ['SVM', 1, 0.13, 0.867, 44, -44],
#  ['DT', 1, 0.14, 0.854, 48, -34],
#  ['RF', 1, 0.14, 0.89, 36, -34],
#  ['KNN', 1, 0.14, 0.848, 50, -50],
#  ['SVM', 1, 0.14, 0.866, 44, -44],
#  ['DT', 1, 0.15, 0.896, 34, -22],
#  ['RF', 1, 0.15, 0.899, 33, -31],
#  ['KNN', 1, 0.15, 0.85, 49, -49],
#  ['SVM', 1, 0.15, 0.877, 40, -40],
#  ['DT', 1, 0.16, 0.892, 35, -21],
#  ['RF', 1, 0.16, 0.907, 30, -28],
#  ['KNN', 1, 0.16, 0.849, 49, -49],
#  ['SVM', 1, 0.16, 0.877, 40, -40],
#  ['DT', 1, 0.17, 0.903, 31, -25],
#  ['RF', 1, 0.17, 0.9, 32, -32],
#  ['KNN', 1, 0.17, 0.879, 39, -39],
#  ['SVM', 1, 0.17, 0.894, 34, -34],
#  ['DT', 1, 0.18, 0.9, 32, -20],
#  ['RF', 1, 0.18, 0.903, 31, -31],
#  ['KNN', 1, 0.18, 0.884, 37, -37],
#  ['SVM', 1, 0.18, 0.893, 34, -34],
#  ['DT', 1, 0.19, 0.868, 42, -26],
#  ['RF', 1, 0.19, 0.896, 33, -31],
#  ['KNN', 1, 0.19, 0.883, 37, -37],
#  ['SVM', 1, 0.19, 0.899, 32, -32],
#  ['DT', 1, 0.2, 0.889, 35, -19],
#  ['RF', 1, 0.2, 0.898, 32, -30],
#  ['KNN', 1, 0.2, 0.883, 37, -37],
#  ['SVM', 1, 0.2, 0.898, 32, -32],
#  ['DT', 1, 0.21, 0.901, 31, -17],
#  ['RF', 1, 0.21, 0.911, 28, -28],
#  ['KNN', 1, 0.21, 0.895, 33, -33],
#  ['SVM', 1, 0.21, 0.898, 32, -32],
#  ['DT', 1, 0.22, 0.904, 30, -16],
#  ['RF', 1, 0.22, 0.9, 31, -31],
#  ['KNN', 1, 0.22, 0.894, 33, -33],
#  ['SVM', 1, 0.22, 0.91, 28, -28],
#  ['DT', 1, 0.23, 0.89, 34, -24],
#  ['RF', 1, 0.23, 0.9, 31, -31],
#  ['KNN', 1, 0.23, 0.896, 32, -32],
#  ['SVM', 1, 0.23, 0.906, 29, -29],
#  ['DT', 1, 0.24, 0.896, 32, -22],
#  ['RF', 1, 0.24, 0.909, 28, -28],
#  ['KNN', 1, 0.24, 0.899, 31, -31],
#  ['SVM', 1, 0.24, 0.912, 27, -27],
#  ['DT', 1, 0.25, 0.901, 30, -18],
#  ['RF', 1, 0.25, 0.901, 30, -28],
#  ['KNN', 1, 0.25, 0.901, 30, -30],
#  ['SVM', 1, 0.25, 0.914, 26, -26],
#  ['DT', 1, 0.26, 0.887, 34, -22],
#  ['RF', 1, 0.26, 0.924, 23, -23],
#  ['KNN', 1, 0.26, 0.904, 29, -29],
#  ['SVM', 1, 0.26, 0.924, 23, -21],
#  ['DT', 1, 0.27, 0.903, 29, -17],
#  ['RF', 1, 0.27, 0.903, 29, -27],
#  ['KNN', 1, 0.27, 0.91, 27, -27],
#  ['SVM', 1, 0.27, 0.927, 22, -20],
#  ['DT', 1, 0.28, 0.899, 30, -18],
#  ['RF', 1, 0.28, 0.906, 28, -28],
#  ['KNN', 1, 0.28, 0.909, 27, -27],
#  ['SVM', 1, 0.28, 0.926, 22, -20],
#  ['DT', 1, 0.29, 0.905, 28, -16],
#  ['RF', 1, 0.29, 0.912, 26, -22],
#  ['KNN', 1, 0.29, 0.909, 27, -27],
#  ['SVM', 1, 0.29, 0.926, 22, -20],
#  ['DT', 1, 0.3, 0.898, 30, -16],
#  ['RF', 1, 0.3, 0.915, 25, -23],
#  ['KNN', 1, 0.3, 0.908, 27, -27],
#  ['SVM', 1, 0.3, 0.932, 20, -18],
#  ['DT', 1, 0.31, 0.904, 28, -18],
#  ['RF', 1, 0.31, 0.921, 23, -21],
#  ['KNN', 1, 0.31, 0.908, 27, -27],
#  ['SVM', 1, 0.31, 0.932, 20, -18],
#  ['DT', 1, 0.32, 0.914, 25, -15],
#  ['RF', 1, 0.32, 0.917, 24, -22],
#  ['KNN', 1, 0.32, 0.914, 25, -25],
#  ['SVM', 1, 0.32, 0.934, 19, -17],
#  ['DT', 1, 0.33, 0.903, 28, -18],
#  ['RF', 1, 0.33, 0.927, 21, -21],
#  ['KNN', 1, 0.33, 0.913, 25, -25],
#  ['SVM', 1, 0.33, 0.931, 20, -16],
#  ['DT', 1, 0.34, 0.912, 25, -11],
#  ['RF', 1, 0.34, 0.933, 19, -17],
#  ['KNN', 1, 0.34, 0.919, 23, -23],
#  ['SVM', 1, 0.34, 0.93, 20, -16],
#  ['DT', 1, 0.35, 0.898, 29, -17],
#  ['RF', 1, 0.35, 0.915, 24, -20],
#  ['KNN', 1, 0.35, 0.919, 23, -23],
#  ['SVM', 1, 0.35, 0.929, 20, -16],
#  ['DT', 1, 0.36, 0.918, 23, -13],
#  ['RF', 1, 0.36, 0.918, 23, -19],
#  ['KNN', 1, 0.36, 0.929, 20, -20],
#  ['SVM', 1, 0.36, 0.95, 14, -10],
#  ['DT', 1, 0.37, 0.918, 23, -15],
#  ['RF', 1, 0.37, 0.943, 16, -12],
#  ['KNN', 1, 0.37, 0.935, 18, -18],
#  ['SVM', 1, 0.37, 0.953, 13, -9],
#  ['DT', 1, 0.38, 0.913, 24, -18],
#  ['RF', 1, 0.38, 0.931, 19, -15],
#  ['KNN', 1, 0.38, 0.939, 17, -17],
#  ['SVM', 1, 0.38, 0.953, 13, -9],
#  ['DT', 1, 0.39, 0.92, 22, -14],
#  ['RF', 1, 0.39, 0.938, 17, -9],
#  ['KNN', 1, 0.39, 0.938, 17, -17],
#  ['SVM', 1, 0.39, 0.949, 14, -10],
#  ['DT', 1, 0.4, 0.912, 24, -14],
#  ['RF', 1, 0.4, 0.938, 17, -11],
#  ['KNN', 1, 0.4, 0.938, 17, -17],
#  ['SVM', 1, 0.4, 0.945, 15, -11],
#  ['DT', 1, 0.41, 0.908, 25, -13],
#  ['RF', 1, 0.41, 0.93, 19, -11],
#  ['KNN', 1, 0.41, 0.937, 17, -17],
#  ['SVM', 1, 0.41, 0.945, 15, -11],
#  ['DT', 1, 0.42, 0.914, 23, -9],
#  ['RF', 1, 0.42, 0.937, 17, -13],
#  ['KNN', 1, 0.42, 0.944, 15, -15],
#  ['SVM', 1, 0.42, 0.955, 12, -8],
#  ['DT', 1, 0.43, 0.932, 18, -6],
#  ['RF', 1, 0.43, 0.932, 18, -12],
#  ['KNN', 1, 0.43, 0.947, 14, -14],
#  ['SVM', 1, 0.43, 0.959, 11, -7],
#  ['DT', 1, 0.44, 0.924, 20, -6],
#  ['RF', 1, 0.44, 0.936, 17, -9],
#  ['KNN', 1, 0.44, 0.947, 14, -14],
#  ['SVM', 1, 0.44, 0.958, 11, -7],
#  ['DT', 1, 0.45, 0.939, 16, -8],
#  ['RF', 1, 0.45, 0.939, 16, -10],
#  ['KNN', 1, 0.45, 0.947, 14, -14],
#  ['SVM', 1, 0.45, 0.958, 11, -7],
#  ['DT', 1, 0.46, 0.931, 18, -6],
#  ['RF', 1, 0.46, 0.95, 13, -11],
#  ['KNN', 1, 0.46, 0.946, 14, -14],
#  ['SVM', 1, 0.46, 0.958, 11, -7],
#  ['DT', 1, 0.47, 0.938, 16, -8],
#  ['RF', 1, 0.47, 0.946, 14, -10],
#  ['KNN', 1, 0.47, 0.95, 13, -13],
#  ['SVM', 1, 0.47, 0.961, 10, -6],
#  ['DT', 1, 0.48, 0.934, 17, -7],
#  ['RF', 1, 0.48, 0.938, 16, -10],
#  ['KNN', 1, 0.48, 0.953, 12, -12],
#  ['SVM', 1, 0.48, 0.961, 10, -6],
#  ['DT', 1, 0.49, 0.929, 18, -10],
#  ['RF', 1, 0.49, 0.933, 17, -7],
#  ['KNN', 1, 0.49, 0.953, 12, -12],
#  ['SVM', 1, 0.49, 0.961, 10, -6],
#  ['DT', 1, 0.5, 0.932, 17, -5],
#  ['RF', 1, 0.5, 0.932, 17, -9],
#  ['KNN', 1, 0.5, 0.952, 12, -12],
#  ['SVM', 1, 0.5, 0.96, 10, -6],
#  ['DT', 1, 0.51, 0.928, 18, -4],
#  ['RF', 1, 0.51, 0.94, 15, -11],
#  ['KNN', 1, 0.51, 0.952, 12, -12],
#  ['SVM', 1, 0.51, 0.96, 10, -6],
#  ['DT', 1, 0.52, 0.935, 16, -8],
#  ['RF', 1, 0.52, 0.947, 13, -5],
#  ['KNN', 1, 0.52, 0.96, 10, -10],
#  ['SVM', 1, 0.52, 0.955, 11, -5],
#  ['DT', 1, 0.53, 0.939, 15, -7],
#  ['RF', 1, 0.53, 0.943, 14, -6],
#  ['KNN', 1, 0.53, 0.959, 10, -10],
#  ['SVM', 1, 0.53, 0.955, 11, -5],
#  ['DT', 1, 0.54, 0.942, 14, -8],
#  ['RF', 1, 0.54, 0.951, 12, -10],
#  ['KNN', 1, 0.54, 0.963, 9, -9],
#  ['SVM', 1, 0.54, 0.955, 11, -5],
#  ['DT', 1, 0.55, 0.929, 17, -5],
#  ['RF', 1, 0.55, 0.938, 15, -5],
#  ['KNN', 1, 0.55, 0.963, 9, -9],
#  ['SVM', 1, 0.55, 0.959, 10, -4],
#  ['DT', 1, 0.56, 0.95, 12, -4],
#  ['RF', 1, 0.56, 0.941, 14, -4],
#  ['KNN', 1, 0.56, 0.967, 8, -8],
#  ['SVM', 1, 0.56, 0.958, 10, -4],
#  ['DT', 1, 0.57, 0.949, 12, -4],
#  ['RF', 1, 0.57, 0.949, 12, -2],
#  ['KNN', 1, 0.57, 0.975, 6, -6],
#  ['SVM', 1, 0.57, 0.958, 10, -2],
#  ['DT', 1, 0.58, 0.936, 15, -3],
#  ['RF', 1, 0.58, 0.949, 12, -2],
#  ['KNN', 1, 0.58, 0.974, 6, -6],
#  ['SVM', 1, 0.58, 0.957, 10, -2],
#  ['DT', 1, 0.59, 0.935, 15, -1],
#  ['RF', 1, 0.59, 0.948, 12, -2],
#  ['KNN', 1, 0.59, 0.978, 5, -5],
#  ['SVM', 1, 0.59, 0.957, 10, -2],
#  ['DT', 1, 0.6, 0.926, 17, 1],
#  ['RF', 1, 0.6, 0.957, 10, 0],
#  ['KNN', 1, 0.6, 0.978, 5, -5],
#  ['SVM', 1, 0.6, 0.961, 9, -1],
#  ['DT', 1, 0.61, 0.921, 18, 2],
#  ['RF', 1, 0.61, 0.947, 12, 0],
#  ['KNN', 1, 0.61, 0.978, 5, -5],
#  ['SVM', 1, 0.61, 0.961, 9, -1],
#  ['DT', 1, 0.62, 0.951, 11, -3],
#  ['RF', 1, 0.62, 0.96, 9, 1],
#  ['KNN', 1, 0.62, 0.982, 4, -4],
#  ['SVM', 1, 0.62, 0.965, 8, 0],
#  ['DT', 1, 0.63, 0.951, 11, -3],
#  ['RF', 1, 0.63, 0.96, 9, 1],
#  ['KNN', 1, 0.63, 0.982, 4, -4],
#  ['SVM', 1, 0.63, 0.964, 8, 0],
#  ['DT', 1, 0.64, 0.95, 11, -3],
#  ['RF', 1, 0.64, 0.959, 9, 1],
#  ['KNN', 1, 0.64, 0.982, 4, -4],
#  ['SVM', 1, 0.64, 0.964, 8, 0],
#  ['DT', 1, 0.65, 0.941, 13, -1],
#  ['RF', 1, 0.65, 0.959, 9, 1],
#  ['KNN', 1, 0.65, 0.982, 4, -4],
#  ['SVM', 1, 0.65, 0.964, 8, 0],
#  ['DT', 1, 0.66, 0.94, 13, -1],
#  ['RF', 1, 0.66, 0.963, 8, 0],
#  ['KNN', 1, 0.66, 0.982, 4, -4],
#  ['SVM', 1, 0.66, 0.963, 8, 0],
#  ['DT', 1, 0.67, 0.94, 13, -1],
#  ['RF', 1, 0.67, 0.958, 9, 1],
#  ['KNN', 1, 0.67, 0.981, 4, -4],
#  ['SVM', 1, 0.67, 0.963, 8, 0],
#  ['DT', 1, 0.68, 0.939, 13, -1],
#  ['RF', 1, 0.68, 0.958, 9, -1],
#  ['KNN', 1, 0.68, 0.981, 4, -4],
#  ['SVM', 1, 0.68, 0.962, 8, 0],
#  ['DT', 1, 0.69, 0.934, 14, 2],
#  ['RF', 1, 0.69, 0.957, 9, 1],
#  ['KNN', 1, 0.69, 0.986, 3, -3],
#  ['SVM', 1, 0.69, 0.967, 7, 1],
#  ['DT', 1, 0.7, 0.909, 19, 9],
#  ['RF', 1, 0.7, 0.957, 9, 1],
#  ['KNN', 1, 0.7, 0.986, 3, -3],
#  ['SVM', 1, 0.7, 0.967, 7, 1],
#  ['DT', 1, 0.71, 0.913, 18, 6],
#  ['RF', 1, 0.71, 0.961, 8, 0],
#  ['KNN', 1, 0.71, 0.986, 3, -3],
#  ['SVM', 1, 0.71, 0.966, 7, 1],
#  ['DT', 1, 0.72, 0.907, 19, 7],
#  ['RF', 1, 0.72, 0.956, 9, 1],
#  ['KNN', 1, 0.72, 0.985, 3, -3],
#  ['SVM', 1, 0.72, 0.966, 7, 1],
#  ['DT', 1, 0.73, 0.916, 17, 5],
#  ['RF', 1, 0.73, 0.956, 9, 1],
#  ['KNN', 1, 0.73, 0.985, 3, -3],
#  ['SVM', 1, 0.73, 0.966, 7, 1],
#  ['DT', 1, 0.74, 0.881, 24, 10],
#  ['RF', 1, 0.74, 0.95, 10, 2],
#  ['KNN', 1, 0.74, 0.985, 3, -3],
#  ['SVM', 1, 0.74, 0.965, 7, 1],
#  ['DT', 1, 0.75, 0.934, 13, 1],
#  ['RF', 1, 0.75, 0.955, 9, 1],
#  ['KNN', 1, 0.75, 0.985, 3, -3],
#  ['SVM', 1, 0.75, 0.965, 7, 1],
#  ['DT', 1, 0.76, 0.929, 14, 4],
#  ['RF', 1, 0.76, 0.964, 7, 3],
#  ['KNN', 1, 0.76, 0.99, 2, -2],
#  ['SVM', 1, 0.76, 0.969, 6, 2],
#  ['DT', 1, 0.77, 0.933, 13, 3],
#  ['RF', 1, 0.77, 0.964, 7, 3],
#  ['KNN', 1, 0.77, 0.99, 2, -2],
#  ['SVM', 1, 0.77, 0.969, 6, 2],
#  ['DT', 1, 0.78, 0.922, 15, 13],
#  ['RF', 1, 0.78, 0.958, 8, 4],
#  ['KNN', 1, 0.78, 0.99, 2, -2],
#  ['SVM', 1, 0.78, 0.969, 6, 2],
#  ['DT', 1, 0.79, 0.926, 14, 10],
#  ['RF', 1, 0.79, 0.968, 6, 4],
#  ['KNN', 1, 0.79, 0.989, 2, -2],
#  ['SVM', 1, 0.79, 0.974, 5, 1],
#  ['DT', 1, 0.8, 0.91, 17, 11],
#  ['RF', 1, 0.8, 0.973, 5, 3],
#  ['KNN', 1, 0.8, 0.995, 1, -1],
#  ['SVM', 1, 0.8, 0.973, 5, 3],
#  ['DT', 1, 0.81, 0.914, 16, 10],
#  ['RF', 1, 0.81, 0.968, 6, 4],
#  ['KNN', 1, 0.81, 0.995, 1, -1],
#  ['SVM', 1, 0.81, 0.973, 5, 3],
#  ['DT', 1, 0.82, 0.929, 13, 5],
#  ['RF', 1, 0.82, 0.967, 6, 4],
#  ['KNN', 1, 0.82, 0.995, 1, -1],
#  ['SVM', 1, 0.82, 0.973, 5, 3],
#  ['DT', 1, 0.83, 0.89, 20, 14],
#  ['RF', 1, 0.83, 0.967, 6, 4],
#  ['KNN', 1, 0.83, 0.995, 1, -1],
#  ['SVM', 1, 0.83, 0.973, 5, 3],
#  ['DT', 1, 0.84, 0.922, 14, 10],
#  ['RF', 1, 0.84, 0.966, 6, 6],
#  ['KNN', 1, 0.84, 1.0, 0, 0],
#  ['SVM', 1, 0.84, 0.978, 4, 4],
#  ['DT', 1, 0.85, 0.944, 10, 8],
#  ['RF', 1, 0.85, 0.972, 5, 5],
#  ['KNN', 1, 0.85, 1.0, 0, 0],
#  ['SVM', 1, 0.85, 0.977, 4, 4],
#  ['DT', 1, 0.86, 0.949, 9, 7],
#  ['RF', 1, 0.86, 0.971, 5, 5],
#  ['KNN', 1, 0.86, 1.0, 0, 0],
#  ['SVM', 1, 0.86, 0.977, 4, 4],
#  ['DT', 1, 0.87, 0.936, 11, 9],
#  ['RF', 1, 0.87, 0.971, 5, 5],
#  ['KNN', 1, 0.87, 1.0, 0, 0],
#  ['SVM', 1, 0.87, 0.977, 4, 4],
#  ['DT', 1, 0.88, 0.953, 8, 6],
#  ['RF', 1, 0.88, 0.971, 5, 5],
#  ['KNN', 1, 0.88, 1.0, 0, 0],
#  ['SVM', 1, 0.88, 0.977, 4, 4],
#  ['DT', 1, 0.89, 0.935, 11, 9],
#  ['RF', 1, 0.89, 0.964, 6, 6],
#  ['KNN', 1, 0.89, 1.0, 0, 0],
#  ['SVM', 1, 0.89, 0.976, 4, 4],
#  ['DT', 1, 0.9, 0.928, 12, 10],
#  ['RF', 1, 0.9, 0.97, 5, 5],
#  ['KNN', 1, 0.9, 1.0, 0, 0],
#  ['SVM', 1, 0.9, 0.976, 4, 4],
#  ['DT', 1, 0.91, 0.921, 13, 11],
#  ['RF', 1, 0.91, 0.964, 6, 6],
#  ['KNN', 1, 0.91, 1.0, 0, 0],
#  ['SVM', 1, 0.91, 0.976, 4, 4],
#  ['DT', 1, 0.92, 0.932, 11, 9],
#  ['RF', 1, 0.92, 0.963, 6, 6],
#  ['KNN', 1, 0.92, 1.0, 0, 0],
#  ['SVM', 1, 0.92, 0.975, 4, 4],
#  ['DT', 1, 0.93, 0.912, 14, 12],
#  ['RF', 1, 0.93, 0.962, 6, 6],
#  ['KNN', 1, 0.93, 1.0, 0, 0],
#  ['SVM', 1, 0.93, 0.975, 4, 4],
#  ['DT', 1, 0.94, 0.918, 13, 11],
#  ['RF', 1, 0.94, 0.968, 5, 5],
#  ['KNN', 1, 0.94, 0.994, 1, 1],
#  ['SVM', 1, 0.94, 0.975, 4, 4],
#  ['DT', 1, 0.95, 0.936, 10, 8],
#  ['RF', 1, 0.95, 0.962, 6, 6],
#  ['KNN', 1, 0.95, 0.994, 1, 1],
#  ['SVM', 1, 0.95, 0.974, 4, 4],
#  ['DT', 1, 0.96, 0.935, 10, 8],
#  ['RF', 1, 0.96, 0.961, 6, 6],
#  ['KNN', 1, 0.96, 0.994, 1, 1],
#  ['SVM', 1, 0.96, 0.974, 4, 4],
#  ['DT', 1, 0.97, 0.921, 12, 12],
#  ['RF', 1, 0.97, 0.967, 5, 5],
#  ['KNN', 1, 0.97, 0.993, 1, 1],
#  ['SVM', 1, 0.97, 0.974, 4, 4],
#  ['DT', 1, 0.98, 0.907, 14, 14],
#  ['RF', 1, 0.98, 0.967, 5, 5],
#  ['KNN', 1, 0.98, 0.993, 1, 1],
#  ['SVM', 1, 0.98, 0.973, 4, 4],
#  ['DT', 1, 0.99, 0.912, 13, 13],
#  ['RF', 1, 0.99, 0.953, 7, 7],
#  ['KNN', 1, 0.99, 0.993, 1, 1],
#  ['SVM', 1, 0.99, 0.973, 4, 4]]

# %%
Weight = []
for i in range(10, 100) :
    labelratio = 0.01 * i  # i: 10--99, ---> 0.1 --0.99
    Weight = Weight + RunAll(bcw, labelratio, 1)
    
Weight
# Out:
# [['DT', 1, 0.1, 0.89, 37, -31],
#  ['RF', 1, 0.1, 0.881, 40, -38],
#  ['KNN', 1, 0.1, 0.818, 61, -61],
#  ['SVM', 1, 0.1, 0.833, 56, -56],
#  ['DT', 1, 0.11, 0.886, 38, -30],
#  ['RF', 1, 0.11, 0.868, 44, -44],
#  ['KNN', 1, 0.11, 0.823, 59, -59],
#  ['SVM', 1, 0.11, 0.841, 53, -53],
#  ['DT', 1, 0.12, 0.883, 39, -29],
#  ['RF', 1, 0.12, 0.873, 42, -42],
#  ['KNN', 1, 0.12, 0.837, 54, -54],
#  ['SVM', 1, 0.12, 0.861, 46, -46],
#  ['DT', 1, 0.13, 0.903, 32, -22],
#  ['RF', 1, 0.13, 0.891, 36, -36],
#  ['KNN', 1, 0.13, 0.842, 52, -52],
#  ['SVM', 1, 0.13, 0.867, 44, -44],
#  ['DT', 1, 0.14, 0.902, 32, -20],
#  ['RF', 1, 0.14, 0.909, 30, -30],
#  ['KNN', 1, 0.14, 0.848, 50, -50],
#  ['SVM', 1, 0.14, 0.866, 44, -44],
#  ['DT', 1, 0.15, 0.874, 41, -33],
#  ['RF', 1, 0.15, 0.893, 35, -33],
#  ['KNN', 1, 0.15, 0.85, 49, -49],
#  ['SVM', 1, 0.15, 0.877, 40, -40],
#  ['DT', 1, 0.16, 0.901, 32, -20],
#  ['RF', 1, 0.16, 0.898, 33, -33],
#  ['KNN', 1, 0.16, 0.849, 49, -49],
#  ['SVM', 1, 0.16, 0.877, 40, -40],
#  ['DT', 1, 0.17, 0.903, 31, -21],
#  ['RF', 1, 0.17, 0.907, 30, -30],
#  ['KNN', 1, 0.17, 0.879, 39, -39],
#  ['SVM', 1, 0.17, 0.894, 34, -34],
#  ['DT', 1, 0.18, 0.878, 39, -27],
#  ['RF', 1, 0.18, 0.9, 32, -30],
#  ['KNN', 1, 0.18, 0.884, 37, -37],
#  ['SVM', 1, 0.18, 0.893, 34, -34],
#  ['DT', 1, 0.19, 0.909, 29, -17],
#  ['RF', 1, 0.19, 0.909, 29, -27],
#  ['KNN', 1, 0.19, 0.883, 37, -37],
#  ['SVM', 1, 0.19, 0.899, 32, -32],
#  ['DT', 1, 0.2, 0.905, 30, -22],
#  ['RF', 1, 0.2, 0.914, 27, -27],
#  ['KNN', 1, 0.2, 0.883, 37, -37],
#  ['SVM', 1, 0.2, 0.898, 32, -32],
#  ['DT', 1, 0.21, 0.875, 39, -27],
#  ['RF', 1, 0.21, 0.907, 29, -29],
#  ['KNN', 1, 0.21, 0.895, 33, -33],
#  ['SVM', 1, 0.21, 0.898, 32, -32],
#  ['DT', 1, 0.22, 0.904, 30, -14],
#  ['RF', 1, 0.22, 0.907, 29, -27],
#  ['KNN', 1, 0.22, 0.894, 33, -33],
#  ['SVM', 1, 0.22, 0.91, 28, -28],
#  ['DT', 1, 0.23, 0.903, 30, -20],
#  ['RF', 1, 0.23, 0.906, 29, -27],
#  ['KNN', 1, 0.23, 0.896, 32, -32],
#  ['SVM', 1, 0.23, 0.906, 29, -29],
#  ['DT', 1, 0.24, 0.886, 35, -25],
#  ['RF', 1, 0.24, 0.906, 29, -27],
#  ['KNN', 1, 0.24, 0.899, 31, -31],
#  ['SVM', 1, 0.24, 0.912, 27, -27],
#  ['DT', 1, 0.25, 0.905, 29, -17],
#  ['RF', 1, 0.25, 0.905, 29, -27],
#  ['KNN', 1, 0.25, 0.901, 30, -30],
#  ['SVM', 1, 0.25, 0.914, 26, -26],
#  ['DT', 1, 0.26, 0.901, 30, -22],
#  ['RF', 1, 0.26, 0.907, 28, -26],
#  ['KNN', 1, 0.26, 0.904, 29, -29],
#  ['SVM', 1, 0.26, 0.924, 23, -21],
#  ['DT', 1, 0.27, 0.913, 26, -18],
#  ['RF', 1, 0.27, 0.923, 23, -23],
#  ['KNN', 1, 0.27, 0.91, 27, -27],
#  ['SVM', 1, 0.27, 0.927, 22, -20],
#  ['DT', 1, 0.28, 0.909, 27, -15],
#  ['RF', 1, 0.28, 0.913, 26, -24],
#  ['KNN', 1, 0.28, 0.909, 27, -27],
#  ['SVM', 1, 0.28, 0.926, 22, -20],
#  ['DT', 1, 0.29, 0.909, 27, -15],
#  ['RF', 1, 0.29, 0.926, 22, -20],
#  ['KNN', 1, 0.29, 0.909, 27, -27],
#  ['SVM', 1, 0.29, 0.926, 22, -20],
#  ['DT', 1, 0.3, 0.891, 32, -20],
#  ['RF', 1, 0.3, 0.922, 23, -21],
#  ['KNN', 1, 0.3, 0.908, 27, -27],
#  ['SVM', 1, 0.3, 0.932, 20, -18],
#  ['DT', 1, 0.31, 0.908, 27, -17],
#  ['RF', 1, 0.31, 0.918, 24, -22],
#  ['KNN', 1, 0.31, 0.908, 27, -27],
#  ['SVM', 1, 0.31, 0.932, 20, -18],
#  ['DT', 1, 0.32, 0.914, 25, -17],
#  ['RF', 1, 0.32, 0.903, 28, -26],
#  ['KNN', 1, 0.32, 0.914, 25, -25],
#  ['SVM', 1, 0.32, 0.934, 19, -17],
#  ['DT', 1, 0.33, 0.913, 25, -17],
#  ['RF', 1, 0.33, 0.917, 24, -22],
#  ['KNN', 1, 0.33, 0.913, 25, -25],
#  ['SVM', 1, 0.33, 0.931, 20, -16],
#  ['DT', 1, 0.34, 0.884, 33, -25],
#  ['RF', 1, 0.34, 0.916, 24, -22],
#  ['KNN', 1, 0.34, 0.919, 23, -23],
#  ['SVM', 1, 0.34, 0.93, 20, -16],
#  ['DT', 1, 0.35, 0.915, 24, -18],
#  ['RF', 1, 0.35, 0.912, 25, -17],
#  ['KNN', 1, 0.35, 0.919, 23, -23],
#  ['SVM', 1, 0.35, 0.929, 20, -16],
#  ['DT', 1, 0.36, 0.904, 27, -15],
#  ['RF', 1, 0.36, 0.929, 20, -18],
#  ['KNN', 1, 0.36, 0.929, 20, -20],
#  ['SVM', 1, 0.36, 0.95, 14, -10],
#  ['DT', 1, 0.37, 0.907, 26, -16],
#  ['RF', 1, 0.37, 0.932, 19, -13],
#  ['KNN', 1, 0.37, 0.935, 18, -18],
#  ['SVM', 1, 0.37, 0.953, 13, -9],
#  ['DT', 1, 0.38, 0.913, 24, -20],
#  ['RF', 1, 0.38, 0.924, 21, -13],
#  ['KNN', 1, 0.38, 0.939, 17, -17],
#  ['SVM', 1, 0.38, 0.953, 13, -9],
#  ['DT', 1, 0.39, 0.916, 23, -7],
#  ['RF', 1, 0.39, 0.938, 17, -15],
#  ['KNN', 1, 0.39, 0.938, 17, -17],
#  ['SVM', 1, 0.39, 0.949, 14, -10],
#  ['DT', 1, 0.4, 0.905, 26, -10],
#  ['RF', 1, 0.4, 0.934, 18, -12],
#  ['KNN', 1, 0.4, 0.938, 17, -17],
#  ['SVM', 1, 0.4, 0.945, 15, -11],
#  ['DT', 1, 0.41, 0.911, 24, -12],
#  ['RF', 1, 0.41, 0.93, 19, -13],
#  ['KNN', 1, 0.41, 0.937, 17, -17],
#  ['SVM', 1, 0.41, 0.945, 15, -11],
#  ['DT', 1, 0.42, 0.922, 21, -11],
#  ['RF', 1, 0.42, 0.948, 14, -12],
#  ['KNN', 1, 0.42, 0.944, 15, -15],
#  ['SVM', 1, 0.42, 0.955, 12, -8],
#  ['DT', 1, 0.43, 0.921, 21, -5],
#  ['RF', 1, 0.43, 0.936, 17, -7],
#  ['KNN', 1, 0.43, 0.947, 14, -14],
#  ['SVM', 1, 0.43, 0.959, 11, -7],
#  ['DT', 1, 0.44, 0.928, 19, -7],
#  ['RF', 1, 0.44, 0.928, 19, -9],
#  ['KNN', 1, 0.44, 0.947, 14, -14],
#  ['SVM', 1, 0.44, 0.958, 11, -7],
#  ['DT', 1, 0.45, 0.931, 18, -6],
#  ['RF', 1, 0.45, 0.943, 15, -11],
#  ['KNN', 1, 0.45, 0.947, 14, -14],
#  ['SVM', 1, 0.45, 0.958, 11, -7],
#  ['DT', 1, 0.46, 0.935, 17, -7],
#  ['RF', 1, 0.46, 0.938, 16, -10],
#  ['KNN', 1, 0.46, 0.946, 14, -14],
#  ['SVM', 1, 0.46, 0.958, 11, -7],
#  ['DT', 1, 0.47, 0.934, 17, -7],
#  ['RF', 1, 0.47, 0.938, 16, -8],
#  ['KNN', 1, 0.47, 0.95, 13, -13],
#  ['SVM', 1, 0.47, 0.961, 10, -6],
#  ['DT', 1, 0.48, 0.934, 17, -9],
#  ['RF', 1, 0.48, 0.938, 16, -10],
#  ['KNN', 1, 0.48, 0.953, 12, -12],
#  ['SVM', 1, 0.48, 0.961, 10, -6],
#  ['DT', 1, 0.49, 0.929, 18, -10],
#  ['RF', 1, 0.49, 0.933, 17, -11],
#  ['KNN', 1, 0.49, 0.953, 12, -12],
#  ['SVM', 1, 0.49, 0.961, 10, -6],
#  ['DT', 1, 0.5, 0.924, 19, -7],
#  ['RF', 1, 0.5, 0.928, 18, -10],
#  ['KNN', 1, 0.5, 0.952, 12, -12],
#  ['SVM', 1, 0.5, 0.96, 10, -6],
#  ['DT', 1, 0.51, 0.924, 19, -5],
#  ['RF', 1, 0.51, 0.936, 16, -8],
#  ['KNN', 1, 0.51, 0.952, 12, -12],
#  ['SVM', 1, 0.51, 0.96, 10, -6],
#  ['DT', 1, 0.52, 0.939, 15, -7],
#  ['RF', 1, 0.52, 0.947, 13, -7],
#  ['KNN', 1, 0.52, 0.96, 10, -10],
#  ['SVM', 1, 0.52, 0.955, 11, -5],
#  ['DT', 1, 0.53, 0.939, 15, -7],
#  ['RF', 1, 0.53, 0.939, 15, -5],
#  ['KNN', 1, 0.53, 0.959, 10, -10],
#  ['SVM', 1, 0.53, 0.955, 11, -5],
#  ['DT', 1, 0.54, 0.938, 15, -7],
#  ['RF', 1, 0.54, 0.942, 14, -8],
#  ['KNN', 1, 0.54, 0.963, 9, -9],
#  ['SVM', 1, 0.54, 0.955, 11, -5],
#  ['DT', 1, 0.55, 0.929, 17, -5],
#  ['RF', 1, 0.55, 0.942, 14, -8],
#  ['KNN', 1, 0.55, 0.963, 9, -9],
#  ['SVM', 1, 0.55, 0.959, 10, -4],
#  ['DT', 1, 0.56, 0.95, 12, -4],
#  ['RF', 1, 0.56, 0.941, 14, -6],
#  ['KNN', 1, 0.56, 0.967, 8, -8],
#  ['SVM', 1, 0.56, 0.958, 10, -4],
#  ['DT', 1, 0.57, 0.949, 12, -6],
#  ['RF', 1, 0.57, 0.954, 11, -3],
#  ['KNN', 1, 0.57, 0.975, 6, -6],
#  ['SVM', 1, 0.57, 0.958, 10, -2],
#  ['DT', 1, 0.58, 0.945, 13, -3],
#  ['RF', 1, 0.58, 0.949, 12, -4],
#  ['KNN', 1, 0.58, 0.974, 6, -6],
#  ['SVM', 1, 0.58, 0.957, 10, -2],
#  ['DT', 1, 0.59, 0.927, 17, 1],
#  ['RF', 1, 0.59, 0.953, 11, -1],
#  ['KNN', 1, 0.59, 0.978, 5, -5],
#  ['SVM', 1, 0.59, 0.957, 10, -2],
#  ['DT', 1, 0.6, 0.93, 16, 0],
#  ['RF', 1, 0.6, 0.952, 11, -1],
#  ['KNN', 1, 0.6, 0.978, 5, -5],
#  ['SVM', 1, 0.6, 0.961, 9, -1],
#  ['DT', 1, 0.61, 0.925, 17, 1],
#  ['RF', 1, 0.61, 0.956, 10, 0],
#  ['KNN', 1, 0.61, 0.978, 5, -5],
#  ['SVM', 1, 0.61, 0.961, 9, -1],
#  ['DT', 1, 0.62, 0.947, 12, -2],
#  ['RF', 1, 0.62, 0.956, 10, 2],
#  ['KNN', 1, 0.62, 0.982, 4, -4],
#  ['SVM', 1, 0.62, 0.965, 8, 0],
#  ['DT', 1, 0.63, 0.946, 12, -2],
#  ['RF', 1, 0.63, 0.96, 9, 1],
#  ['KNN', 1, 0.63, 0.982, 4, -4],
#  ['SVM', 1, 0.63, 0.964, 8, 0],
#  ['DT', 1, 0.64, 0.946, 12, -2],
#  ['RF', 1, 0.64, 0.959, 9, 1],
#  ['KNN', 1, 0.64, 0.982, 4, -4],
#  ['SVM', 1, 0.64, 0.964, 8, 0],
#  ['DT', 1, 0.65, 0.95, 11, -3],
#  ['RF', 1, 0.65, 0.955, 10, 0],
#  ['KNN', 1, 0.65, 0.982, 4, -4],
#  ['SVM', 1, 0.65, 0.964, 8, 0],
#  ['DT', 1, 0.66, 0.95, 11, -3],
#  ['RF', 1, 0.66, 0.954, 10, 0],
#  ['KNN', 1, 0.66, 0.982, 4, -4],
#  ['SVM', 1, 0.66, 0.963, 8, 0],
#  ['DT', 1, 0.67, 0.94, 13, -1],
#  ['RF', 1, 0.67, 0.958, 9, 1],
#  ['KNN', 1, 0.67, 0.981, 4, -4],
#  ['SVM', 1, 0.67, 0.963, 8, 0],
#  ['DT', 1, 0.68, 0.944, 12, -2],
#  ['RF', 1, 0.68, 0.962, 8, 0],
#  ['KNN', 1, 0.68, 0.981, 4, -4],
#  ['SVM', 1, 0.68, 0.962, 8, 0],
#  ['DT', 1, 0.69, 0.934, 14, 0],
#  ['RF', 1, 0.69, 0.957, 9, 1],
#  ['KNN', 1, 0.69, 0.986, 3, -3],
#  ['SVM', 1, 0.69, 0.967, 7, 1],
#  ['DT', 1, 0.7, 0.909, 19, 7],
#  ['RF', 1, 0.7, 0.957, 9, 1],
#  ['KNN', 1, 0.7, 0.986, 3, -3],
#  ['SVM', 1, 0.7, 0.967, 7, 1],
#  ['DT', 1, 0.71, 0.918, 17, 5],
#  ['RF', 1, 0.71, 0.961, 8, 0],
#  ['KNN', 1, 0.71, 0.986, 3, -3],
#  ['SVM', 1, 0.71, 0.966, 7, 1],
#  ['DT', 1, 0.72, 0.902, 20, 8],
#  ['RF', 1, 0.72, 0.961, 8, 0],
#  ['KNN', 1, 0.72, 0.985, 3, -3],
#  ['SVM', 1, 0.72, 0.966, 7, 1],
#  ['DT', 1, 0.73, 0.916, 17, 7],
#  ['RF', 1, 0.73, 0.956, 9, 1],
#  ['KNN', 1, 0.73, 0.985, 3, -3],
#  ['SVM', 1, 0.73, 0.966, 7, 1],
#  ['DT', 1, 0.74, 0.9, 20, 6],
#  ['RF', 1, 0.74, 0.955, 9, 1],
#  ['KNN', 1, 0.74, 0.985, 3, -3],
#  ['SVM', 1, 0.74, 0.965, 7, 1],
#  ['DT', 1, 0.75, 0.929, 14, 2],
#  ['RF', 1, 0.75, 0.955, 9, 1],
#  ['KNN', 1, 0.75, 0.985, 3, -3],
#  ['SVM', 1, 0.75, 0.965, 7, 1],
#  ['DT', 1, 0.76, 0.913, 17, 9],
#  ['RF', 1, 0.76, 0.964, 7, 3],
#  ['KNN', 1, 0.76, 0.99, 2, -2],
#  ['SVM', 1, 0.76, 0.969, 6, 2],
#  ['DT', 1, 0.77, 0.918, 16, 8],
#  ['RF', 1, 0.77, 0.974, 5, 3],
#  ['KNN', 1, 0.77, 0.99, 2, -2],
#  ['SVM', 1, 0.77, 0.969, 6, 2],
#  ['DT', 1, 0.78, 0.927, 14, 10],
#  ['RF', 1, 0.78, 0.964, 7, 3],
#  ['KNN', 1, 0.78, 0.99, 2, -2],
#  ['SVM', 1, 0.78, 0.969, 6, 2],
#  ['DT', 1, 0.79, 0.942, 11, 9],
#  ['RF', 1, 0.79, 0.968, 6, 4],
#  ['KNN', 1, 0.79, 0.989, 2, -2],
#  ['SVM', 1, 0.79, 0.974, 5, 1],
#  ['DT', 1, 0.8, 0.936, 12, 6],
#  ['RF', 1, 0.8, 0.963, 7, 5],
#  ['KNN', 1, 0.8, 0.995, 1, -1],
#  ['SVM', 1, 0.8, 0.973, 5, 3],
#  ['DT', 1, 0.81, 0.919, 15, 9],
#  ['RF', 1, 0.81, 0.973, 5, 3],
#  ['KNN', 1, 0.81, 0.995, 1, -1],
#  ['SVM', 1, 0.81, 0.973, 5, 3],
#  ['DT', 1, 0.82, 0.918, 15, 9],
#  ['RF', 1, 0.82, 0.967, 6, 4],
#  ['KNN', 1, 0.82, 0.995, 1, -1],
#  ['SVM', 1, 0.82, 0.973, 5, 3],
#  ['DT', 1, 0.83, 0.901, 18, 12],
#  ['RF', 1, 0.83, 0.962, 7, 5],
#  ['KNN', 1, 0.83, 0.995, 1, -1],
#  ['SVM', 1, 0.83, 0.973, 5, 3],
#  ['DT', 1, 0.84, 0.939, 11, 7],
#  ['RF', 1, 0.84, 0.972, 5, 5],
#  ['KNN', 1, 0.84, 1.0, 0, 0],
#  ['SVM', 1, 0.84, 0.978, 4, 4],
#  ['DT', 1, 0.85, 0.91, 16, 14],
#  ['RF', 1, 0.85, 0.972, 5, 5],
#  ['KNN', 1, 0.85, 1.0, 0, 0],
#  ['SVM', 1, 0.85, 0.977, 4, 4],
#  ['DT', 1, 0.86, 0.949, 9, 7],
#  ['RF', 1, 0.86, 0.966, 6, 6],
#  ['KNN', 1, 0.86, 1.0, 0, 0],
#  ['SVM', 1, 0.86, 0.977, 4, 4],
#  ['DT', 1, 0.87, 0.919, 14, 12],
#  ['RF', 1, 0.87, 0.971, 5, 5],
#  ['KNN', 1, 0.87, 1.0, 0, 0],
#  ['SVM', 1, 0.87, 0.977, 4, 4],
#  ['DT', 1, 0.88, 0.93, 12, 10],
#  ['RF', 1, 0.88, 0.971, 5, 5],
#  ['KNN', 1, 0.88, 1.0, 0, 0],
#  ['SVM', 1, 0.88, 0.977, 4, 4],
#  ['DT', 1, 0.89, 0.947, 9, 7],
#  ['RF', 1, 0.89, 0.97, 5, 5],
#  ['KNN', 1, 0.89, 1.0, 0, 0],
#  ['SVM', 1, 0.89, 0.976, 4, 4],
#  ['DT', 1, 0.9, 0.934, 11, 9],
#  ['RF', 1, 0.9, 0.964, 6, 6],
#  ['KNN', 1, 0.9, 1.0, 0, 0],
#  ['SVM', 1, 0.9, 0.976, 4, 4],
#  ['DT', 1, 0.91, 0.933, 11, 9],
#  ['RF', 1, 0.91, 0.97, 5, 5],
#  ['KNN', 1, 0.91, 1.0, 0, 0],
#  ['SVM', 1, 0.91, 0.976, 4, 4],
#  ['DT', 1, 0.92, 0.938, 10, 8],
#  ['RF', 1, 0.92, 0.969, 5, 5],
#  ['KNN', 1, 0.92, 1.0, 0, 0],
#  ['SVM', 1, 0.92, 0.975, 4, 4],
#  ['DT', 1, 0.93, 0.919, 13, 11],
#  ['RF', 1, 0.93, 0.962, 6, 6],
#  ['KNN', 1, 0.93, 1.0, 0, 0],
#  ['SVM', 1, 0.93, 0.975, 4, 4],
#  ['DT', 1, 0.94, 0.937, 10, 8],
#  ['RF', 1, 0.94, 0.968, 5, 5],
#  ['KNN', 1, 0.94, 0.994, 1, 1],
#  ['SVM', 1, 0.94, 0.975, 4, 4],
#  ['DT', 1, 0.95, 0.91, 14, 12],
#  ['RF', 1, 0.95, 0.962, 6, 6],
#  ['KNN', 1, 0.95, 0.994, 1, 1],
#  ['SVM', 1, 0.95, 0.974, 4, 4],
#  ['DT', 1, 0.96, 0.922, 12, 10],
#  ['RF', 1, 0.96, 0.961, 6, 6],
#  ['KNN', 1, 0.96, 0.994, 1, 1],
#  ['SVM', 1, 0.96, 0.974, 4, 4],
#  ['DT', 1, 0.97, 0.914, 13, 13],
#  ['RF', 1, 0.97, 0.967, 5, 5],
#  ['KNN', 1, 0.97, 0.993, 1, 1],
#  ['SVM', 1, 0.97, 0.974, 4, 4],
#  ['DT', 1, 0.98, 0.907, 14, 14],
#  ['RF', 1, 0.98, 0.96, 6, 6],
#  ['KNN', 1, 0.98, 0.993, 1, 1],
#  ['SVM', 1, 0.98, 0.973, 4, 4],
#  ['DT', 1, 0.99, 0.905, 14, 14],
#  ['RF', 1, 0.99, 0.959, 6, 6],
#  ['KNN', 1, 0.99, 0.993, 1, 1],
#  ['SVM', 1, 0.99, 0.973, 4, 4]]

# %% [markdown]
# # 5. Get some important statistics for various labelratio and models with groupby and other statistics

# %% [markdown]
# # 5.1 Convert previous results into DataFrame so that we can use powerful tools(including groupby) in DataFrame to do the analysis

# %%
DefaultDF = pd.DataFrame(Default, columns = ['Model', 'Weight', 'LabelRatio', 'Accuracy', 'N_errors', 'Bias'])
WeightDF = pd.DataFrame(Weight, columns = ['Model', 'Weight', 'LabelRatio', 'Accuracy', 'N_errors', 'Bias'])

# %%
DefaultDF.head()
# Out:
#   Model  Weight  LabelRatio  Accuracy  N_errors  Bias
# 0    DT       1        0.10     0.884        39   -29
# 1    RF       1        0.10     0.872        43   -43
# 2   KNN       1        0.10     0.818        61   -61
# 3   SVM       1        0.10     0.833        56   -56
# 4    DT       1        0.11     0.886        38   -32

# %%
WeightDF.head()
# Out:
#   Model  Weight  LabelRatio  Accuracy  N_errors  Bias
# 0    DT       1        0.10     0.890        37   -31
# 1    RF       1        0.10     0.881        40   -38
# 2   KNN       1        0.10     0.818        61   -61
# 3   SVM       1        0.10     0.833        56   -56
# 4    DT       1        0.11     0.886        38   -30

# %%
DefaultDF.Bias.sum()
# Out:
# -3472

# %%
DefaultDF.describe()
# Out:
#        Weight  LabelRatio    Accuracy    N_errors        Bias
# count   360.0  360.000000  360.000000  360.000000  360.000000
# mean      1.0    0.545000    0.938500   16.388889   -9.644444
# std       0.0    0.260153    0.035844   12.328100   14.866396
# min       1.0    0.100000    0.818000    0.000000  -61.000000
# 25%       1.0    0.320000    0.912000    7.000000  -18.000000
# 50%       1.0    0.545000    0.941500   13.000000   -5.000000
# 75%       1.0    0.770000    0.964250   24.000000    1.000000
# max       1.0    0.990000    1.000000   61.000000   14.000000

# %%
WeightDF.describe()
# Out:
#        Weight  LabelRatio    Accuracy    N_errors        Bias
# count   360.0  360.000000  360.000000  360.000000  360.000000
# mean      1.0    0.545000    0.938631   16.344444   -9.650000
# std       0.0    0.260153    0.035569   12.217765   14.825625
# min       1.0    0.100000    0.818000    0.000000  -61.000000
# 25%       1.0    0.320000    0.913000    7.000000  -18.000000
# 50%       1.0    0.545000    0.942000   13.500000   -6.000000
# 75%       1.0    0.770000    0.964250   24.000000    1.000000
# max       1.0    0.990000    1.000000   61.000000   14.000000

# %%
DefaultDF[DefaultDF.LabelRatio > 0.7].describe()
# Out:
#        Weight  LabelRatio    Accuracy    N_errors        Bias
# count   116.0  116.000000  116.000000  116.000000  116.000000
# mean      1.0    0.850000    0.963431    6.534483    3.844828
# std       0.0    0.084029    0.027433    5.022438    4.003484
# min       1.0    0.710000    0.881000    0.000000   -3.000000
# 25%       1.0    0.780000    0.952250    3.750000    1.000000
# 50%       1.0    0.850000    0.969000    5.000000    4.000000
# 75%       1.0    0.920000    0.979750    9.000000    6.000000
# max       1.0    0.990000    1.000000   24.000000   14.000000

# %%
WeightDF[WeightDF.LabelRatio > 0.7].describe()
# Out:
#        Weight  LabelRatio   Accuracy    N_errors        Bias
# count   116.0  116.000000  116.00000  116.000000  116.000000
# mean      1.0    0.850000    0.96356    6.500000    3.896552
# std       0.0    0.084029    0.02733    4.947551    4.028980
# min       1.0    0.710000    0.90000    0.000000   -3.000000
# 25%       1.0    0.780000    0.95350    3.750000    1.000000
# 50%       1.0    0.850000    0.96950    5.000000    4.000000
# 75%       1.0    0.920000    0.97975    9.000000    6.000000
# max       1.0    0.990000    1.00000   20.000000   14.000000

# %%
DefaultDF[DefaultDF.LabelRatio < 0.5].describe()
# Out:
#        Weight  LabelRatio    Accuracy    N_errors       Bias
# count   160.0  160.000000  160.000000  160.000000  160.00000
# mean      1.0    0.295000    0.911463   26.737500  -22.80000
# std       0.0    0.115796    0.029639   10.902361   12.30626
# min       1.0    0.100000    0.818000   10.000000  -61.00000
# 25%       1.0    0.197500    0.898000   18.000000  -31.00000
# 50%       1.0    0.295000    0.912000   26.000000  -20.00000
# 75%       1.0    0.392500    0.933250   32.000000  -13.75000
# max       1.0    0.490000    0.961000   61.000000   -6.00000

# %%
WeightDF[WeightDF.LabelRatio < 0.5].describe()
# Out:
#        Weight  LabelRatio    Accuracy    N_errors        Bias
# count   160.0  160.000000  160.000000  160.000000  160.000000
# mean      1.0    0.295000    0.911713   26.643750  -22.768750
# std       0.0    0.115796    0.029108   10.710805   12.244995
# min       1.0    0.100000    0.818000   10.000000  -61.000000
# 25%       1.0    0.197500    0.898750   18.000000  -29.250000
# 50%       1.0    0.295000    0.912000   26.000000  -20.000000
# 75%       1.0    0.392500    0.932250   32.000000  -13.750000
# max       1.0    0.490000    0.961000   61.000000   -5.000000

# %%
DefaultDF[(DefaultDF.LabelRatio < 0.5) & (DefaultDF.LabelRatio > 0.2)].describe()
# Out:
#        Weight  LabelRatio    Accuracy    N_errors        Bias
# count   116.0  116.000000  116.000000  116.000000  116.000000
# mean      1.0    0.350000    0.924534   21.655172  -17.344828
# std       0.0    0.084029    0.019306    6.588664    7.543616
# min       1.0    0.210000    0.887000   10.000000  -33.000000
# 25%       1.0    0.280000    0.908750   16.750000  -23.000000
# 50%       1.0    0.350000    0.925000   22.000000  -17.000000
# 75%       1.0    0.420000    0.938000   27.250000  -11.000000
# max       1.0    0.490000    0.961000   34.000000   -6.000000

# %%
WeightDF[(WeightDF.LabelRatio < 0.5) & (WeightDF.LabelRatio > 0.2)].describe()
# Out:
#        Weight  LabelRatio    Accuracy    N_errors        Bias
# count   116.0  116.000000  116.000000  116.000000  116.000000
# mean      1.0    0.350000    0.924095   21.775862  -17.431034
# std       0.0    0.084029    0.019300    6.566167    7.519510
# min       1.0    0.210000    0.875000   10.000000  -33.000000
# 25%       1.0    0.280000    0.908750   17.000000  -23.250000
# 50%       1.0    0.350000    0.924000   22.000000  -17.000000
# 75%       1.0    0.420000    0.938000   27.000000  -11.000000
# max       1.0    0.490000    0.961000   39.000000   -5.000000

# %%
DefaultDF.groupby('Model').sum()
# Out:
#        Weight  LabelRatio  Accuracy  N_errors  Bias
# Model
# DT         90       49.05    82.651      1835  -489
# KNN        90       49.05    85.466      1321 -1309
# RF         90       49.05    84.557      1436  -828
# SVM        90       49.05    85.186      1308  -846

# %%
WeightDF.groupby('Model').sum()
# Out:
#        Weight  LabelRatio  Accuracy  N_errors  Bias
# Model
# DT         90       49.05    82.691      1819  -493
# KNN        90       49.05    85.466      1321 -1309
# RF         90       49.05    84.564      1436  -826
# SVM        90       49.05    85.186      1308  -846

# %%
DefaultDF[DefaultDF.LabelRatio < 0.5].groupby('Model').sum()
# Out:
#        Weight  LabelRatio  Accuracy  N_errors  Bias
# Model
# DT         40        11.8    36.209      1133  -697
# KNN        40        11.8    36.197      1157 -1157
# RF         40        11.8    36.625      1013  -901
# SVM        40        11.8    36.803       975  -893

# %%
WeightDF[WeightDF.LabelRatio < 0.5].groupby('Model').sum()
# Out:
#        Weight  LabelRatio  Accuracy  N_errors  Bias
# Model
# DT         40        11.8    36.254      1117  -701
# KNN        40        11.8    36.197      1157 -1157
# RF         40        11.8    36.620      1014  -892
# SVM        40        11.8    36.803       975  -893
